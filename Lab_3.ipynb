# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi134/FMML_L1/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:22:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  96.5MB/s    in 0.7s
#
# 2025-03-16 06:22:44 (96.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20351  1510.05572v1  How could we solve the machine learning and th...    cs
# 30169  1711.08238v6  Most existing Convolutional Neural Networks(CN...    cs
# 25188  1506.04340v1  In this paper we present Deep Secure Encoding:...    cs
# 15131   1405.5654v1  Although the parallel corpus has an irreplacea...    cs
# 27801  1704.05817v1  It is difficult to recover the motion field fr...    cs
# ...             ...                                                ...   ...
# 32966  1511.08987v1  This essay investigates the question of how th...    cs
# 11256  1506.05855v4  A central problem in statistics is model selec...  stat
# 22355  1603.03805v2  This paper investigates the phase retrieval pr...  stat
# 1417   1704.07816v2  We propose introspective convolutional network...    cs
# 31130  1802.04467v1  Unpaired Image-to-Image translation aims to co...    cs
#
#                                                    title  year  \
# 20351                       On the Computability of AIXI  2015
# 30169  Multi-Level Recurrent Residual Networks for Ac...  2017
# 25188  Deep Secure Encoding: An Application to Face R...  2015
# 15131  Machine Translation Model based on Non-paralle...  2014
# 27801         Learn to Model Motion from Blurry Footages  2017
# ...                                                  ...   ...
# 32966  How do the naive Bayes classifier and the Supp...  2015
# 11256  Information-based inference for singular model...  2015
# 22355  Median-Truncated Nonconvex Approach for Phase ...  2016
# 1417   Introspective Classification with Convolutiona...  2017
# 31130  An Optimized Architecture for Unpaired Image-t...  2018
#
#                                                 keywords
# 20351  [artificial, intelligence, computation, solomo...
# 30169  [convolutional, recognition, difficult, inform...
# 25188  [framework, classification, biometric, protect...
# 15131  [irreplaceable, translation, resources, inesti...
# 27801  [difficult, photometric, framework, interleavi...
# ...                                                  ...
# 32966  [investigates, classifier, classifier, algorit...
# 11256  [statistics, selection, competing, stochastic,...
# 22355  [investigates, retrieval, magnitudes, measurem...
# 1417   [introspective, convolutional, emphasize, impo...
# 31130  [translation, providing, demonstrated, generat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20351    [artificial, intelligence, computation, solomo...
# 30169    [convolutional, recognition, difficult, inform...
# 25188    [framework, classification, biometric, protect...
# 15131    [irreplaceable, translation, resources, inesti...
# 27801    [difficult, photometric, framework, interleavi...
#                                ...
# 22246    [introduce, forecasting, equivalent, regressio...
# 39533    [developing, automated, automated, solutions, ...
# 12530    [characterize, asymptotic, performance, nonpar...
# 12474    [crowdsourcing, important, crowdworkers, somet...
# 22452    [predicting, locations, observations, interpol...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8926 words.
# Out of those 4547 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2ae28808-44da-483e-98ba-46c086b6146b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ae28808-44da-483e-98ba-46c086b6146b")) {                    Plotly.newPlot(                        "2ae28808-44da-483e-98ba-46c086b6146b",                        [{"x":["approximated","induction","hierarchy","computation","computable","intelligence","incomputable","maximizes","corresponding","artificial","reinforcement","spatiotemporal","representations","difficult","complexity","computing","information","convolutional","framework","comparable","breakthroughs","achieving","efficiency","performance","independently","consistently","employing","additional","alternative","complementary","baselines","incorporates","significant","connection","recognition","improvements","recurrent","verification","classification","biometric","protection","application","assumptions","identification","furthermore","unrealistic","databases","templates","functions","statistical","combining","translation","processing","experimental","supervised","extracting","sentences","unlabeled","irreplaceable","expanding","potential","respective","classifier","resources","transductive","effectively","strengths","especially","alignment","architecture","capability","synthetic","deconvolution","filtering","iterative","modelling","directional","simultaneously","competitive","similarity","photometric","integrated","traditional","approaches","interleaving","estimation","precision","learnable","parameters","effective","encourage","iteration","multivariate","algorithm","discriminant","responses","formulate","optimization","construct","constrains","different","presented","optimizing","parameter","segmentation","annotation","critically","prediction","boundaries","predicted","distributions","demonstrate","perception","limitations","collected","irrelevant","detection","advantage","transforms","unification","specialized","expensive","simulators","canonical","notorious","extensive","prohibitively","advantages","unsupervised","generalization","suboptimal","experiments","autonomous","interpretable","intermediate","annotated","superiority","representation","structured","permutations","divergence","effectiveness","stochastic","distributed","algorithms","aggregation","retrieval","applications","inference","specifically","objective","automatic","guaranteed","submodular","efficient","determination","variational","documenting","relevance","derivation","implementation","implement","regression","providing","available","expansion","structures","assigning","neighbors","satisfies","distances","conditions","comparison","recursively","concerned","selecting","comparisons","competitors","probability","logarithmic","incremental","nonparametric","mechanical","parametric","properties","particular","leveraging","technique","semiparametric","equations","trajectory","geometric","isotropic","continuously","trajectories","consequently","gradients","differential","arbitrary","quadratic"],"y":[19,16,31,161,9,90,2,14,131,140,114,9,252,150,187,118,682,381,514,104,5,83,155,868,28,33,28,107,95,38,61,38,230,40,375,104,141,37,512,8,5,257,61,98,180,3,60,12,214,162,109,105,324,386,196,59,60,48,2,8,124,18,151,70,7,110,21,115,54,267,61,130,15,70,66,50,20,119,119,151,11,46,184,433,4,197,68,20,273,236,20,34,21,786,16,32,61,312,95,6,760,194,47,118,225,57,6,237,41,46,120,555,49,61,60,16,337,87,22,9,30,62,6,21,2,166,4,76,154,109,11,582,64,22,29,80,33,362,105,4,22,192,117,90,596,29,103,429,215,154,144,170,37,15,368,10,53,1,36,14,144,70,123,97,299,14,130,14,17,13,43,160,141,9,13,41,32,3,180,13,30,12,7,36,195,262,39,243,1,28,25,73,5,23,27,31,33,33,75,40],"type":"bar"},{"x":["approximated","induction","hierarchy","computation","comp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4547,), (4547, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Point</span> <span style=''>wise</span> <span style=''>Map</span> <span style=''>Recovery</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6875);'>Refinement</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functional</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>Correspondence</span> <br/><br/><span style=''>Since</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduction</span> <span style=''>in</span> <span style=''>the</span> <span style=''>shape</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.34426229508196726);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style=''>maps</span> <span style=''>have</span> <span style=''>met</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.30303030303030304);'>considerable</span> <span style=''>success</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compactly</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>represent</span> <span style=''>dense</span> <span style='background-color:rgba(0, 255, 0, 0.7391304347826088);'>correspondences</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>deformable</span> <span style=''>shapes</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>shape</span> <span style=''>matching</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7441860465116279);'>segmentation</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>of</span> <span style=''>large</span> <span style=''>shape</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collections</span> <span style=''>Despite</span> <span style=''>the</span> <span style=''>numerous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.40038684719535783);'>representation</span> <span style=''>however</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converting</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style=''>map</span> <span style=''>back</span> <span style=''>to</span> <span style=''>a</span> <span style=''>point</span> <span style=''>to</span> <span style=''>point</span> <span style=''>map</span> <span style=''>has</span> <span style=''>received</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprisingly</span> <span style=''>limited</span> <span style=''>interest</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>general</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>point</span> <span style=''>wise</span> <span style=''>map</span> <span style=''>recovery</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style=''>maps</span> <span style=''>In</span> <span style=''>doing</span> <span style=''>so</span> <span style=''>we</span> <span style=''>rule</span> <span style=''>out</span> <span style=''>many</span> <span style=''>of</span> <span style=''>t ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Posterior</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>on</span> <span style=''>Streams</span> <br/><br/><span style=''>Many</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>problems</span> <span style=''>involve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inferences</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>data</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>data</span> <span style=''>is</span> <span style=''>not</span> <span style=''>easily</span> <span style=''>amenable</span> <span style=''>to</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>which</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>on</span> <span style=''>finite</span> <span style=''>data</span> <span style=''>We</span> <span style=''>develop</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayes</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style=''>modeling</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>streams</span> <span style=''>of</span> <span style=''>data</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>a</span> <span style=''>new</span> <span style=''>type</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>with</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>We</span> <span style=''>study</span> <span style=''>our</span> <span style=''>method</span> <span style=''>with</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>allocation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>mixtures</span> <span style=''>on</span> <span style=''>several</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>sets</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Image</span> <span style=''>Labeling</span> <span style=''>Based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.6129032258064516);'>Wasserstein</span> <span style=''>Messages</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3035714285714286);'>Geometric</span> <span style='background-color:rgba(0, 255, 0, 0.441860465116279);'>Assignment</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>Maximum</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Posteriori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>based</span> <span style=''>on</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.380281690140845);'>utilizing</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.6129032258064516);'>Wasserstein</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>for</span> <span style=''>coupling</span> <span style='background-color:rgba(0, 255, 0, 0.441860465116279);'>assignment</span> <span style=''>measures</span> <span style=''>across</span> <span style=''>edges</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style=''>a</span> <span style=''>given</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>is</span> <span style=''>smoothly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximated</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.441860465116279);'>assignment</span> <span style=''>manifold</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplicative</span> <span style=''>update</span> <span style=''>scheme</span> <span style=''>combines</span> <span style=''>in</span> <span style=''>a</span> <span style=''>single</span> <span style=''>process</span> <span style=''>(i)</span> <span style='background-color:rgba(0, 255, 0, 0.3035714285714286);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.3142857142857144);'>integration</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>gradient</span> <span style=''>flow</span> <span style=''>and</span> <span style=''>(ii)</span> <span style=''>rounding</span> <span style=''>to</span> <span style=''>integral</span> <span style='background-color:rgba(0, 255, 0, 0.3284132841328413);'>solutions</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>represent</span> <span style=''>valid</span> <span style=''>labelings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Throughout</span> <span style=''>this</span> <span style=''>process</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454546);'>marginalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>known</span> <span style=''>from</span> <span style=''>t ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Generating</span> <span style=''>Music</span> <span style=''>Medleys</span> <span style=''>via</span> <span style=''>Playing</span> <span style=''>Music</span> <span style=''>Puzzle</span> <span style=''>Games</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Generating</span> <span style=''>music</span> <span style=''>medleys</span> <span style=''>is</span> <span style=''>about</span> <span style=''>finding</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>music</span> <span style=''>clips</span> <span style=''>Toward</span> <span style=''>this</span> <span style=''>goal</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>self</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>called</span> <span style=''>the</span> <span style=''>music</span> <span style=''>puzzle</span> <span style=''>game</span> <span style=''>to</span> <span style=''>train</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>models</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>music</span> <span style=''>In</span> <span style=''>essence</span> <span style=''>such</span> <span style=''>a</span> <span style=''>game</span> <span style=''>requires</span> <span style=''>machines</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correctly</span> <span style=''>sort</span> <span style=''>a</span> <span style=''>few</span> <span style=''>multisecond</span> <span style=''>music</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fragments</span> <span style=''>In</span> <span style=''>the</span> <span style=''>training</span> <span style=''>stage</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>model</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>multiple</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overlapping</span> <span style=''>fragment</span> <span style=''>pairs</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style=''>songs</span> <span style=''>and</span> <span style=''>seeking</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>given</span> <span style=''>pair</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consecutive</span> <span style=''>and</span> <span style=''>is</span> <span style=''>in</span> <span style=''>the</span> <span style=''>correct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>chronological</span> <span style=''>order</span> <span style=''>For</span> <span style=''>testing</span> <span style=''>we</span> <span style=''>design</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>puzzle</span> <span style=''>games</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulty</span> <span style=''>levels</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>one</span> <span style=''>being</span> <span style=''>music</span> <span style=''>medley</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13087490961677511)
# 	experimental (0.13955169920462762)
# 	processing (0.11713665943600868)
# 	architecture (0.09652928416485901)
# 	segmentation (0.08134490238611713)
# 	information (0.24656543745480838)
# 	detection (0.12183658712942878)
# 	different (0.274765003615329)
# 	convolutional (0.13774403470715835)
# 	recognition (0.13557483731019523)
#
# Some Statistics words are:
# 	variables (0.13323500491642085)
# 	statistical (0.147984267453294)
# 	theoretical (0.14749262536873156)
# 	stochastic (0.14110127826941987)
# 	algorithm (0.3864306784660767)
# 	estimation (0.1750245821042281)
# 	inference (0.1902654867256637)
# 	distribution (0.18780727630285152)
# 	dimensional (0.19223205506391347)
# 	regression (0.18387413962635202)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c978c882-bca3-4f7a-ab9f-0d4e8faebf11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c978c882-bca3-4f7a-ab9f-0d4e8faebf11")) {                    Plotly.newPlot(                        "c978c882-bca3-4f7a-ab9f-0d4e8faebf11",                        [{"x":["approximated","induction","hierarchy","computation","computable","intelligence","incomputable","maximizes","corresponding","artificial","reinforcement","spatiotemporal","representations","difficult","complexity","computing","information","convolutional","framework","comparable","breakthroughs","achieving","efficiency","performance","independently","consistently","employing","additional","alternative","complementary","baselines","incorporates","significant","connection","recognition","improvements","recurrent","verification","classification","biometric","protection","application","assumptions","identification","furthermore","unrealistic","databases","templates","functions","statistical","combining","translation","processing","experimental","supervised","extracting","sentences","unlabeled","irreplaceable","expanding","potential","respective","classifier","resources","transductive","effectively","strengths","especially","alignment","architecture","capability","synthetic","deconvolution","filtering","iterative","modelling","directional","simultaneously","competitive","similarity","photometric","integrated","traditional","approaches","interleaving","estimation","precision","learnable","parameters","effective","encourage","iteration","multivariate","algorithm","discriminant","responses","formulate","optimization","construct","constrains","different","presented","optimizing","parameter","segmentation","annotation","critically","prediction","boundaries","predicted","distributions","demonstrate","perception","limitations","collected","irrelevant","detection","advantage","transforms","unification","specialized","expensive","simulators","canonical","notorious","extensive","prohibitively","advantages","unsupervised","generalization","suboptimal","experiments","autonomous","interpretable","intermediate","annotated","superiority","representation","structured","permutations","divergence","effectiveness","stochastic","distributed","algorithms","aggregation","retrieval","applications","inference","specifically","objective","automatic","guaranteed","submodular","efficient","determination","variational","documenting","relevance","derivation","implementation","implement","regression","providing","available","expansion","structures","assigning","neighbors","satisfies","distances","conditions","comparison","recursively","concerned","selecting","comparisons","competitors","probability","logarithmic","incremental","nonparametric","mechanical","parametric","properties","particular","leveraging","technique","semiparametric","equations","trajectory","geometric","isotropic","continuously","trajectories","consequently","gradients","differential","arbitrary","quadratic","naturally","solutions","convergence","distribution","population","underlying","differentiable","evolution","monotonic","parametrized","deterministic","discretization","strategies","composite","continuous","depending","introduced","dimensional","membership","adjacency","normalized","associated","subsequent","components","recovering","embedding","laplacian","assignments","eigenvalues","blockmodel","dominates","corollary","eigenvectors","covariance","exclusive","iterations","physiological","significantly","investigates","processed","accepting","introducing","arguments","summarization","semantics","argumentation","equivalence","respectively","handwritten","carefully","degradation","implementations","realization","designing","consumpt ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	blockmodel
# 	dominates
# 	methylation
# 	factorizes
# 	methodologically
# 	emphdirectly
# 	changepoints
# 	interpolated
# 	stratification
# 	bernstein
# 	contamination
# 	agglomeration
# 	satisfactorily
# 	sparsistency
# 	manageable
# 	procrustes
# 	unobservable
# 	submanifold
# 	practiced
# 	discharge
# Some words which never appear in Statistics papers:
# 	incomputable
# 	breakthroughs
# 	irreplaceable
# 	photometric
# 	notorious
# 	argumentation
# 	reconfigurable
# 	benefited
# 	sparsified
# 	conversing
# 	reflectance
# 	comprehensively
# 	syntactic
# 	attentional
# 	arithmetics
# 	subtraction
# 	readability
# 	deblurring
# 	magnified
# 	discernible

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.1049150805725465e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
